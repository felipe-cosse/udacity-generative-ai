# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

#os.environ['OPENAI_API_KEY'] = "your-key-here"


#print(os.environ)

# %%
from openai import OpenAI
from pprint import pprint

# Initialize OpenAI client
api_key = os.getenv("OPENAI_API_KEY", "your-api-key-here")
client = OpenAI(
    api_key=api_key,
    base_url="https://openai.vocareum.com/v1" if api_key.startswith("voc") else None
)

completion = client.chat.completions.create(
  model="gpt-4.1",
  messages=[
    {"role": "user", "content": "Give me a short description of what an embedding is"}
  ],
  logprobs=True,
  top_logprobs=5
)

pprint(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='An **embedding** is a way of representing objects—such as words, sentences, or images—as fixed-length numerical vectors. These vectors capture the meaning or characteristics of the objects, allowing them to be processed and compared by machine learning algorithms. Embeddings are widely used in natural language processing, recommendation systems, and computer vision.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)

# %%
pprint(completion.choices[0].logprobs)
# Out:
# ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='An', bytes=[65, 110], logprob=-5.9153885558771435e-06, top_logprobs=[TopLogprob(token='An', bytes=[65, 110], logprob=-5.9153885558771435e-06), TopLogprob(token='**', bytes=[42, 42], logprob=-12.703130722045898), TopLogprob(token='In', bytes=[73, 110], logprob=-12.812505722045898), TopLogprob(token='Sure', bytes=[83, 117, 114, 101], logprob=-19.2812557220459), TopLogprob(token=' An', bytes=[32, 65, 110], logprob=-20.0000057220459)]), ChatCompletionTokenLogprob(token=' **', bytes=[32, 42, 42], logprob=-0.053944218903779984, top_logprobs=[TopLogprob(token=' **', bytes=[32, 42, 42], logprob=-0.053944218903779984), TopLogprob(token=' embedding', bytes=[32, 101, 109, 98, 101, 100, 100, 105, 110, 103], logprob=-3.0070691108703613), TopLogprob(token=' *', bytes=[32, 42], logprob=-5.835194110870361), TopLogprob(token=' ***', bytes=[32, 42, 42, 42], logprob=-8.85081958770752), TopLogprob(token='**', bytes=[42, 42], logprob=-12.39769458770752)]), ChatCompletionTokenLogprob(token='embedding', bytes=[101, 109, 98, 101, 100, 100, 105, 110, 103], logprob=0.0, top_logprobs=[TopLogprob(token='embedding', bytes=[101, 109, 98, 101, 100, 100, 105, 110, 103], logprob=0.0), TopLogprob(token='"', bytes=[34], logprob=-24.4375), TopLogprob(token='emb', bytes=[101, 109, 98], logprob=-24.84375), TopLogprob(token='encoding', bytes=[101, 110, 99, 111, 100, 105, 110, 103], logprob=-25.578125), TopLogprob(token='_embedding', bytes=[95, 101, 109, 98, 101, 100, 100, 105, 110, 103], logprob=-26.65625)]), ChatCompletionTokenLogprob(token='**', bytes=[42, 42], logprob=0.0, top_logprobs=[TopLogprob(token='**', bytes=[42, 42], logprob=0.0), TopLogprob(token='*', bytes=[42], logprob=-19.203125), TopLogprob(token='**,', bytes=[42, 42, 44], logprob=-19.34375), TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-21.125), TopLogprob(token=' **', bytes=[32, 42, 42], logprob=-22.9375)]), ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-4.320199877838604e-07, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-4.320199877838604e-07), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-15.015625), TopLogprob(token=' refers', bytes=[32, 114, 101, 102, 101, 114, 115], logprob=-17.5234375), TopLogprob(token=' (', bytes=[32, 40], logprob=-20.375), TopLogprob(token='\u202f', bytes=[226, 128, 175], logprob=-20.5390625)]), ChatCompletionTokenLogprob(token=' a', bytes=[32, 97], logprob=-1.3856492842023727e-06, top_logprobs=[TopLogprob(token=' a', bytes=[32, 97], logprob=-1.3856492842023727e-06), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-13.539063453674316), TopLogprob(token=' an', bytes=[32, 97, 110], logprob=-17.750001907348633), TopLogprob(token='\u202f', bytes=[226, 128, 175], logprob=-19.328126907348633), TopLogprob(token=' numerical', bytes=[32, 110, 117, 109, 101, 114, 105, 99, 97, 108], logprob=-19.742189407348633)]), ChatCompletionTokenLogprob(token=' way', bytes=[32, 119, 97, 121], logprob=-0.3032599687576294, top_logprobs=[TopLogprob(token=' way', bytes=[32, 119, 97, 121], logprob=-0.3032599687576294), TopLogprob(token=' numerical', bytes=[32, 110, 117, 109, 101, 114, 105, 99, 97, 108], logprob=-1.8032599687576294), TopLogprob(token=' mathematical', bytes=[32, 109, 97, 116, 104, 101, 109, 97, 116, 105, 99, 97, 108], logprob=-2.47513484954834), TopLogprob(token=' representation', bytes=[32, 114, 101, 112, 114, 101, 115, 101, 110, 116, 97, 116, 105, 111, 110], logprob=-4.56888484954834), TopLogprob(token=' numeric', bytes=[32, 110, 117, 109, 101, 114, 105, 99], logprob=-6.60013484954834)]), ChatCompletionTokenLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.05243373289704323, top_logprobs=[TopLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.05243373289704323), TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-2.974308729171753), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-20.946964263916016), TopLogprob(token='\u202f', bytes=[2 ...

# %%
completion
# Out:
# ChatCompletion(id='chatcmpl-E9uHnJY0H9AnzoeAbEg3W99OoFHF9', choices=[Choice(finish_reason='stop', index=0, logprobs=ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='An', bytes=[65, 110], logprob=-5.9153885558771435e-06, top_logprobs=[TopLogprob(token='An', bytes=[65, 110], logprob=-5.9153885558771435e-06), TopLogprob(token='**', bytes=[42, 42], logprob=-12.703130722045898), TopLogprob(token='In', bytes=[73, 110], logprob=-12.812505722045898), TopLogprob(token='Sure', bytes=[83, 117, 114, 101], logprob=-19.2812557220459), TopLogprob(token=' An', bytes=[32, 65, 110], logprob=-20.0000057220459)]), ChatCompletionTokenLogprob(token=' **', bytes=[32, 42, 42], logprob=-0.053944218903779984, top_logprobs=[TopLogprob(token=' **', bytes=[32, 42, 42], logprob=-0.053944218903779984), TopLogprob(token=' embedding', bytes=[32, 101, 109, 98, 101, 100, 100, 105, 110, 103], logprob=-3.0070691108703613), TopLogprob(token=' *', bytes=[32, 42], logprob=-5.835194110870361), TopLogprob(token=' ***', bytes=[32, 42, 42, 42], logprob=-8.85081958770752), TopLogprob(token='**', bytes=[42, 42], logprob=-12.39769458770752)]), ChatCompletionTokenLogprob(token='embedding', bytes=[101, 109, 98, 101, 100, 100, 105, 110, 103], logprob=0.0, top_logprobs=[TopLogprob(token='embedding', bytes=[101, 109, 98, 101, 100, 100, 105, 110, 103], logprob=0.0), TopLogprob(token='"', bytes=[34], logprob=-24.4375), TopLogprob(token='emb', bytes=[101, 109, 98], logprob=-24.84375), TopLogprob(token='encoding', bytes=[101, 110, 99, 111, 100, 105, 110, 103], logprob=-25.578125), TopLogprob(token='_embedding', bytes=[95, 101, 109, 98, 101, 100, 100, 105, 110, 103], logprob=-26.65625)]), ChatCompletionTokenLogprob(token='**', bytes=[42, 42], logprob=0.0, top_logprobs=[TopLogprob(token='**', bytes=[42, 42], logprob=0.0), TopLogprob(token='*', bytes=[42], logprob=-19.203125), TopLogprob(token='**,', bytes=[42, 42, 44], logprob=-19.34375), TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-21.125), TopLogprob(token=' **', bytes=[32, 42, 42], logprob=-22.9375)]), ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-4.320199877838604e-07, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-4.320199877838604e-07), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-15.015625), TopLogprob(token=' refers', bytes=[32, 114, 101, 102, 101, 114, 115], logprob=-17.5234375), TopLogprob(token=' (', bytes=[32, 40], logprob=-20.375), TopLogprob(token='\u202f', bytes=[226, 128, 175], logprob=-20.5390625)]), ChatCompletionTokenLogprob(token=' a', bytes=[32, 97], logprob=-1.3856492842023727e-06, top_logprobs=[TopLogprob(token=' a', bytes=[32, 97], logprob=-1.3856492842023727e-06), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-13.539063453674316), TopLogprob(token=' an', bytes=[32, 97, 110], logprob=-17.750001907348633), TopLogprob(token='\u202f', bytes=[226, 128, 175], logprob=-19.328126907348633), TopLogprob(token=' numerical', bytes=[32, 110, 117, 109, 101, 114, 105, 99, 97, 108], logprob=-19.742189407348633)]), ChatCompletionTokenLogprob(token=' way', bytes=[32, 119, 97, 121], logprob=-0.3032599687576294, top_logprobs=[TopLogprob(token=' way', bytes=[32, 119, 97, 121], logprob=-0.3032599687576294), TopLogprob(token=' numerical', bytes=[32, 110, 117, 109, 101, 114, 105, 99, 97, 108], logprob=-1.8032599687576294), TopLogprob(token=' mathematical', bytes=[32, 109, 97, 116, 104, 101, 109, 97, 116, 105, 99, 97, 108], logprob=-2.47513484954834), TopLogprob(token=' representation', bytes=[32, 114, 101, 112, 114, 101, 115, 101, 110, 116, 97, 116, 105, 111, 110], logprob=-4.56888484954834), TopLogprob(token=' numeric', bytes=[32, 110, 117, 109, 101, 114, 105, 99], logprob=-6.60013484954834)]), ChatCompletionTokenLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.05243373289704323, top_logprobs=[TopLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.05243373289704323), TopLogprob(token=' to', bytes=[32, 116, 111], logprob=-2.9743087291717 ...
