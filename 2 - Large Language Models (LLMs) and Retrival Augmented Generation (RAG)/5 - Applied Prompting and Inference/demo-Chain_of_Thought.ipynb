# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

#os.environ['OPENAI_API_KEY'] = "your key here"


#print(os.environ)

# %%
from openai import OpenAI

api_key = os.getenv("OPENAI_API_KEY", "your-api-key-here")
client = OpenAI(
    api_key=api_key,
    base_url="https://openai.vocareum.com/v1" if api_key.startswith("voc") else None
)

prompt = """How would you measure the diameter of the planet Earth using Eratosthenes method?
"""

completion = client.chat.completions.create(
  model="gpt-4",
  messages=[
    {"role": "user", "content": prompt}
  ]
)

print(completion.choices[0].message.content)
# Out:
# Eratosthenes' method involves the observation of shadows in two different geographical locations. Below is a simplified step-by-step guide on how to measure the Earth's diameter using Eratosthenes method:
#
# 1. Choose two locations that are on the same longitudinal line (It means, both the locations should be north of each other), The distance between these two locations should also be known. It is preferable that one of the locations is on the equator.
#
# 2. Wait for the Summer Solstice (the longest day of the year). At local noon, place a stick in the ground at a 90-degree angle at both locations.
#
# 3. Measure the length of the shadow cast by the stick in both the locations. Note that, at the equator, the stick will cast no shadow because the sun will be exactly overhead.
#
# 4. The shadow at the other location will however, be some length. This is because the sun will not be directly overhead.
#
# 5. The difference in the shadow lengths is due to the curvature of the Earth. By measuring the angle of the shadow cast at the non-equator site, using simple geometric relationships, you can calculate the circumference of the Earth.
#
# 6. For example, if the shadow angle difference is 1 degree, which corresponds to 1/360th of a complete circle, the straight line distance between the two locations can be multiplied by 360 to give an estimate for the Earth's circumference.
#
# 7. Once you have the circumference, to calculate the diameter of the Earth, divide the calculated circumference by Pi (3.1416).
#
# Eratosthenes in 240 BC had precisely done this calculation using the cities of Alexandria and Syene (now Aswan), which are roughly on the same longitude, and he came remarkably close to the currently accepted figure. His value was within 2% of the currently accepted value.

# %%
from openai import OpenAI

api_key = os.getenv("OPENAI_API_KEY", "your-api-key-here")
client = OpenAI(
    api_key=api_key,
    base_url="https://openai.vocareum.com/v1" if api_key.startswith("voc") else None
)

prompt = """How would you measure the diameter of the planet Earth using Eratosthenes method?

Give a step by step process to achieve this.
"""

completion = client.chat.completions.create(
  model="gpt-4",
  messages=[
    {"role": "user", "content": prompt}
  ]
)

print(completion.choices[0].message.content)
# Out:
# 1. Eratosthenes was able to calculate the Earth's diameter using only a few simple tools and observations.
#
# 2. First, he noted that at local noon on the summer solstice in the ancient city of Syene (now Aswan, Egypt), the Sun was directly overhead as there was no shadow cast by a vertical stick.
#
# 3. However, at the same time in Alexandria, roughly 800 kilometers to the north, a vertical stick did cast a shadow.
#
# 4. Eratosthenes measured the angle of this shadow to be about 7.2 degrees.
#
# 5. Assuming that the Earth is a sphere, Eratosthenes realized that this angle was 7/360ths of a full circle.
#
# 6. He reasoned that the distance from Alexandria to Syene must be approximately 7/360ths of Earth's total circumference.
#
# 7. Using the distance between the two cities (800km), which was a known distance in the ancient world, he multiplied this distance by 360/7 to get the total circumference of the Earth, which is approximately 40,000 kilometers.
#
# 8. To get the diameter, one has to divide the circumference by π (pi). Using the standard approximation of 3.14 for pi, the diameter of Earth is around 12,742 kilometers.
#
# 9. As more accurate measurements became available, the accuracy of Eratosthenes’s estimate was confirmed, showing that his method was both reliable and valid.
#
# Note: Local distance measurements and angles would need to be adjusted based on one's specific location and the time of year. But the general method — measuring the angle of the sun's rays and extrapolating to find the Earth's circumference can be replicated.
