# %% [markdown]
# # Exercise: Teach an LLM to Spell with Group Relative Policy Optimization (GRPO)

# %% [markdown]
# Large language models (LLMs) are notoriously bad at spelling. This is partly because tokenizers break words into smaller pieces, so the model learns about sub-word units rather than whole words and their spellings.
#
# In this exercise, you'll use Group Relative Policy Optimization (GRPO) and a technique called Parameter-Efficient Fine-Tuning (PEFT) with Low-Rank Adaptation (LoRA) to teach a small LLM how to spell words. This is a classic example of teaching a model a new skill that isn't well-represented in its pre-training data.
#
# ## What you'll do in this notebook
#
# 1.  **Setup**: Import libraries and configure the environment.
# 2.  **Load the tokenizer and base model**: Use a small, instruction-tuned model as our starting point.
# 3.  **Create the dataset**: Generate a simple dataset of words and their correct spellings.
# 4.  **Evaluate the base model**: Test the model's spelling ability *before* fine-tuning to establish a baseline.
# 5.  **Configure LoRA and train**: Attach a LoRA adapter to the model and fine-tune it on the spelling dataset.
# 6.  **Evaluate the fine-tuned model**: Test the model again to see if its spelling has improved.

# %% [markdown]
# ## Setup

# %%
# Setup imports
# No changes needed in this cell

import os
import torch
from datasets import Dataset

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
)
from peft import LoraConfig, get_peft_model
from trl import SFTTrainer, SFTConfig

# Use GPU, MPS, or CPU, in that order of preference
if torch.cuda.is_available():
    device = torch.device("cuda")  # NVIDIA GPU
elif torch.backends.mps.is_available():
    device = torch.device("mps")  # Apple Silicon
else:
    device = torch.device("cpu")
torch.set_num_threads(max(1, os.cpu_count() // 2))
print("Using device:", device)
# Out:
# Using device: mps

# %% [markdown]
# ## Step 1. Load the tokenizer and base model
#
# The model `HuggingFaceTB/SmolLM2-135M-Instruct` is a small, instruction-tuned model that's suitable for this exercise. It has 135 million parameters, making it lightweight and efficient for fine-tuning. It's not the most powerful model, but it's a good choice for demonstrating the concepts of SFT and PEFT with LoRA, especially on a CPU or limited GPU resources.

# %%
# Student task: Load the model and tokenizer, and copy the model to the device.
# TODO: Complete the sections with **********

# See: https://huggingface.co/docs/transformers/en/models
# See: https://huggingface.co/docs/transformers/en/fast_tokenizers

# Model ID for SmolLM2-135M-Instruct
model_id = "***********"

# Load the tokenizer
tokenizer = "***********"

# Load the model
model = "***********"

# Copy the model to the device (GPU, MPS, or CPU)
model = "***********"

# Model ID for SmolLM2-135M-Instruct
model_id = "HuggingFaceTB/SmolLM2-135M-Instruct"

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Load the model
model = AutoModelForCausalLM.from_pretrained(
    model_id,
)

# Copy the model to the device (GPU, MPS, or CPU)
model = model.to(device)

print("Model parameters (total):", sum(p.numel() for p in model.parameters()))
# Out:
# Model parameters (total): 134515008

# %% [markdown]
# ## Step 2. Create the dataset

# %%
# Create a list of words of different lengths
# No changes are needed in this cell.

# fmt: off
ALL_WORDS = [
    "idea", "glow", "rust", "maze", "echo", "wisp", "veto", "lush", "gaze", "knit", "fume", "plow",
    "void", "oath", "grim", "crisp", "lunar", "fable", "quest", "verge", "brawn", "elude", "aisle",
    "ember", "crave", "ivory", "mirth", "knack", "wryly", "onset", "mosaic", "velvet", "sphinx",
    "radius", "summit", "banner", "cipher", "glisten", "mantle", "scarab", "expose", "fathom",
    "tavern", "fusion", "relish", "lantern", "enchant", "torrent", "capture", "orchard", "eclipse",
    "frescos", "triumph", "absolve", "gossipy", "prelude", "whistle", "resolve", "zealous",
    "mirage", "aperture", "sapphire",
]
# fmt: on

# %%
# Student Task: Create a Hugging Face Dataset with the prompt that asks the model to spell the word
# with hyphens between the letters.
# TODO: Complete the sections with **********


def generate_records():
    for word in ALL_WORDS:
        yield {
            # We will use the GRPOTrainer which expects to receieve formatted prompts
            # to pass to the LLM
            # https://huggingface.co/docs/trl/main/en/grpo_trainer
            # "**********": f"**********",
            # Before using GRPOTrainer, will run a few epochs of supervised-fine tuning (SFT)
            # which can be useful to give an initial nudge to the model. Thus we need to provide
            # the gold standard answer.
            # See the documentation for more details:
            # https://huggingface.co/docs/trl/en/sft_trainer#expected-dataset-type-and-format
            # "**********": "-".join(word).upper() + ".",
            # GRPOTrainer does not expect a completion, but we can add extra columns to our dataset
            # that our reward functions will use to grade the completions provided by the LLM.
            "prompt": (
                            f"You spell words with hyphens between the letters like this W-O-R-D.\nWord:\n{word}\n\n"
                            + "Spelling:\n"
                        ),
            "completion": "-".join(word).upper() + ".",
            "word": word,
            "spelling": "-".join(word).upper(),
        }


ds = Dataset.from_generator(generate_records)

ds = ds.train_test_split(test_size=0.1, seed=42)

# Show the first item of the train split
ds["train"][0]
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# {'prompt': 'You spell words with hyphens between the letters like this W-O-R-D.\nWord:\ntriumph\n\nSpelling:\n',
#  'completion': 'T-R-I-U-M-P-H.',
#  'word': 'triumph',
#  'spelling': 'T-R-I-U-M-P-H'}

# %% [markdown]
# ## Step 3. Evaluate the base model
#
# Before we fine-tune the model, let's see how it performs on the spelling task. We'll create a helper function to generate a spelling for a given word and compare it to the correct answer.

# %%
# Create a helper function that will help us visualize the performance of the model
# No changes needed in this cell


def check_spelling(
    model, tokenizer, prompt: str, actual_spelling: str, max_new_tokens: int = 20
) -> (str, str):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    gen = model.generate(
        **inputs, max_new_tokens=max_new_tokens, use_cache=False
    )  # No parameters = greedy search
    output = tokenizer.decode(gen[0], skip_special_tokens=True)

    # Extract the generated spelling from the full output string
    proposed_spelling = output.split("Spelling:\n")[-1].strip().split("\n")[0].strip()

    # strip any whitepsace from the actual spelling
    actual_spelling = actual_spelling.strip()

    print(
        f"Proposed: {proposed_spelling} | Actual: {actual_spelling} "
        f"| Matches: {'✅' if proposed_spelling == actual_spelling else '❌'}"
    )

    # Remove hyphens for a character-by-character comparison
    proposed_spelling = proposed_spelling.replace("-", "")
    actual_spelling = actual_spelling.replace("-", "")

    # Calculate the proportion of the spelling that was correct
    num_correct = sum(1 for a, b in zip(actual_spelling, proposed_spelling) if a == b)

    return num_correct / len(actual_spelling)  # Return proportion correct

# %%
# Student task: Evaluate the base model's spelling ability
# We expect it to perform poorly, as it hasn't been trained for this task.

proportion_correct = 0.0

for example in ds["train"].select(range(20)):
    prompt = example["prompt"]
    spelling = example["spelling"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=spelling,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/20.0 words correct")
# Out:
# Proposed: trium | Actual: T-R-I-U-M-P-H | Matches: ❌
# Proposed: sapp | Actual: S-A-P-P-H-I-R-E | Matches: ❌
# Proposed: expose | Actual: E-X-P-O-S-E | Matches: ❌
# Proposed: fres | Actual: F-R-E-S-C-O-S | Matches: ❌
# Proposed: wisp | Actual: W-I-S-P | Matches: ❌
# Proposed: mi-er-ge | Actual: M-I-R-A-G-E | Matches: ❌
# Proposed: ivory | Actual: I-V-O-R-Y | Matches: ❌
# Proposed: onset | Actual: O-N-S-E-T | Matches: ❌
# Proposed: elude | Actual: E-L-U-D-E | Matches: ❌
# Proposed: sphinx | Actual: S-P-H-I-N-X | Matches: ❌
# Proposed: brawn | Actual: B-R-A-W-N | Matches: ❌
# Proposed: goss | Actual: G-O-S-S-I-P-Y | Matches: ❌
# Proposed: enchant | Actual: E-N-C-H-A-N-T | Matches: ❌
# Proposed: tavern | Actual: T-A-V-E-R-N | Matches: ❌
# Proposed: whistle | Actual: W-H-I-S-T-L-E | Matches: ❌
# Proposed: W-O-R-D | Actual: C-A-P-T-U-R-E | Matches: ❌
# Proposed: echo | Actual: E-C-H-O | Matches: ❌
# Proposed: mirth | Actual: M-I-R-T-H | Matches: ❌
# Proposed: cris | Actual: C-R-I-S-P | Matches: ❌
# Proposed: zeal | Actual: Z-E-A-L-O-U-S | Matches: ❌
# 0.0/20.0 words correct

# %% [markdown]
# As expected, the base model is terrible at spelling. It mostly just repeats the word back. Now, let's fine-tune it.

# %% [markdown]
# ## Step 4. Configure LoRA and train the model

# %% [markdown]
# Let’s attach a LoRA adapter to the base model. We use a LoRA config so only a tiny fraction of parameters are trainable. Read more here: [LoRA](https://huggingface.co/docs/peft/main/en/conceptual_guides/lora).

# %%
# Student task: Configure LoRA for a causal LM and wrap the model with get_peft_model
# Complete the sections with **********

# Print how many params are trainable at first
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(
    f"Trainable params BEFORE: {trainable:,} / {total:,} ({100 * trainable / total:.2f}%)"
)

# See: https://huggingface.co/docs/peft/package_reference/lora
# lora_config = LoraConfig(
#     r=**********,                 # Rank of the update matrices. Lower value = fewer trainable parameters.
#     lora_alpha=**********,        # LoRA scaling factor.
#     lora_dropout=**********,      # Dropout probability for LoRA layers.
#     bias="none",
#     task_type=**********,         # Causal Language Modeling.
# )
# # Wrap the base model with get_peft_model
# model = get_peft_model(**********, **********)
lora_config = LoraConfig(
    r=64,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
)
model = get_peft_model(model, lora_config)


# Print the number of trainable parameters after applying LoRA
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(
    f"Trainable params AFTER: {trainable:,} / {total:,} ({100 * trainable / total:.2f}%)"
)
# Out:
# Trainable params BEFORE: 134,515,008 / 134,515,008 (100.00%)
# Trainable params AFTER: 3,686,400 / 138,201,408 (2.67%)

# %% [markdown]
# Now let’s set the training arguments. We'll use `SFTConfig` from the TRL library, which is a wrapper around the standard `TrainingArguments`. We keep epochs, batch size, and sequence length modest to finish training quickly.

# %%
# Train the model for a few epochs using SFT before GRPO as in certain cases
# they can work together synergystically.
# See: https://arxiv.org/html/2507.08267v1
# No changes needed here

output_dir = "data/model"

training_args = SFTConfig(
    output_dir=output_dir,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=2,
    num_train_epochs=10,
    learning_rate=5 * 1e-4,
    logging_steps=20,
    eval_strategy="steps",
    eval_steps=20,
    save_strategy="no",
    report_to=[],
    fp16=False,
    lr_scheduler_type="cosine",
)

trainer = SFTTrainer(
    model=model,
    train_dataset=ds["train"],
    eval_dataset=ds["test"],
    args=training_args,
)
trainer.train()

proportion_correct = 0.0

for example in ds["train"].select(range(20)):
    prompt = example["prompt"]
    spelling = example["spelling"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=spelling,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/20.0 words correct")
# Out:
# Map:   0%|          | 0/55 [00:00<?, ? examples/s]
# Converting train dataset to ChatML:   0%|          | 0/55 [00:00<?, ? examples/s]
# Applying chat template to train dataset:   0%|          | 0/55 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/55 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/55 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7 [00:00<?, ? examples/s]
# Converting eval dataset to ChatML:   0%|          | 0/7 [00:00<?, ? examples/s]
# Applying chat template to eval dataset:   0%|          | 0/7 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/7 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/7 [00:00<?, ? examples/s]
#   0%|          | 0/70 [00:00<?, ?it/s]
# /Users/felipecosse/Docker/Udacity Generative AI/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# {'loss': 2.214, 'grad_norm': 0.42802512645721436, 'learning_rate': 0.0004058724504646834, 'mean_token_accuracy': 0.6008083440363408, 'epoch': 2.86}
#   0%|          | 0/2 [00:00<?, ?it/s]
# {'eval_loss': 1.3987942934036255, 'eval_runtime': 0.136, 'eval_samples_per_second': 51.471, 'eval_steps_per_second': 14.706, 'eval_mean_token_accuracy': 0.7678792774677277, 'epoch': 2.86}
# {'loss': 0.9207, 'grad_norm': 0.1627601832151413, 'learning_rate': 0.00019436976651092142, 'mean_token_accuracy': 0.8491814762353898, 'epoch': 5.71}
#   0%|          | 0/2 [00:00<?, ?it/s]
# {'eval_loss': 0.9105186462402344, 'eval_runtime': 0.0606, 'eval_samples_per_second': 115.534, 'eval_steps_per_second': 33.01, 'eval_mean_token_accuracy': 0.845649003982544, 'epoch': 5.71}
# {'loss': 0.76, 'grad_norm': 0.11977754533290863, 'learning_rate': 2.4757783024395242e-05, 'mean_token_accuracy': 0.8768488258123398, 'epoch': 8.57}
#   0%|          | 0/2 [00:00<?, ?it/s]
# {'eval_loss': 0.8905519247055054, 'eval_runtime': 0.0587, 'eval_samples_per_second': 119.275, 'eval_steps_per_second': 34.079, 'eval_mean_token_accuracy': 0.8498862981796265, 'epoch': 8.57}
# {'train_runtime': 14.6389, 'train_samples_per_second': 37.571, 'train_steps_per_second': 4.782, 'train_loss': 1.2200344971248083, 'mean_token_accuracy': 0.8771865159273148, 'epoch': 10.0}
# Proposed: T-R-I-M-P-O-V-I-A-Z. | Actual: T-R-I-U-M-P-H | Matches: ❌
# Proposed: S-A-P-I-B-R. | Actual: S-A-P-P-H-I-R-E | Matches: ❌
# Proposed: E-P-S-T-E-R. | Actual: E-X-P-O-S-E | Matches: ❌
# Proposed: F-S-R-E-C-O-S. | Actual: F-R-E-S-C-O-S | Matches: ❌
# Proposed: W-O-P-S-I-C-E. | Actual: W-I-S-P | Matches: ❌
# Proposed: M-I-A-R-E-G. | Actual: M-I-R-A-G-E | Matches: ❌
# Proposed: I-V-O-Y-Y. | Actual: I-V-O-R-Y | Matches: ❌
# Proposed: O-N-S-T-E-R. | Actual: O-N-S-E-T | Matches: ❌
# Proposed: E-L-E-A-U-D. | Actual: E-L-U-D-E | Matches: ❌
# Proposed: S-P-H-I-N-E. | Actual: S-P-H-I-N-X | Matches: ❌
# Proposed: B-R-A-N-Y. | Actual: B-R-A-W-N | Matches: ❌
# Proposed: G-O-S-H-O-P. | Actual: G-O-S-S-I-P-Y | Matches: ❌
# Proposed: E-N-C-H-A-N. | Actual: E-N-C-H-A-N-T | Matches: ❌
# Proposed: T-A-A-N-A. | Actual: T-A-V-E-R-N | Matches: ❌
# Proposed: W-H-I-S-T. | Actual: W-H-I-S-T-L-E | Matches: ❌
# Proposed: C-U-P-E-R-I-N-G. | Actual: C-A-P-T-U-R-E | Matches: ❌
# Proposed: E-C-O-R-E. | Actual: E-C-H-O | Matches: ❌
# Proposed: M-I-T-E-R. | Actual: M-I-R-T-H | Matches: ❌
# Proposed: C-R-I-S-P. | Actual: C-R-I-S-P | Matches: ❌
# Proposed: Z-E-A-L-O-V-E-R. | Actual: Z-E-A-L-O-U-S | Matches: ❌
# 10.734523809523807/20.0 words correct

# %% [markdown]
# The number of words has slightly increased. Let's try training using GRPO now.
#
# First let's create some reward functions.

# %%
# Student Task: Create a helper function proportion_correct that takes a word and
# a proposed spelling from the LLM and returns a score where every matched character
# adds +1 and every  mismatched character subtracts 1 from the reward--including the
# hyphens.
# TODO: Replace occurences of **********

import re


def proportion_correct(word, proposed_spelling):
    correct_spelling = "-".join(word).upper()

    score = 0.0

    # Pad to the same length to handle extra characters
    max_len = max(len(correct_spelling), len(proposed_spelling))
    proposed_spelling_padded = proposed_spelling.ljust(max_len, " ")
    correct_spelling_padded = correct_spelling.ljust(max_len, " ")

    for a, b in zip(correct_spelling_padded, proposed_spelling_padded):
        # Add 1 for matched characters, and subtract one for mismatched
        # **********
        if a == b:
            score += 1
        else:
            score -= 1


    return score / (
        len(correct_spelling)
    )  # Normalize by length of spelling, including dashes


assert proportion_correct("hello", "H-E-L-L-O") == 9 / 9
assert proportion_correct("hello", "H-E-L-") == 3 / 9
assert proportion_correct("hello", "H-E-L-L-O!") == 8 / 9

# %%
# Create a `reward_spelling` function that receives a batch of completions and the associated word values
# No changes needed here

import numpy as np


def reward_spelling(completions, word, **kwargs):
    """Reward function that rewards completions with more unique letters."""

    completion_strings = [
        completion.split("\n")[0].strip() for completion in completions
    ]
    words = [w for w in word]

    rewards = [proportion_correct(w, c) for w, c in zip(words, completion_strings)]

    # When training, GRPO will pass multiple completions and words to this function.
    # We print just the first one to observe what is happening under the hood.
    print("=====")
    print(
        "Completion example first line:",
        words[0],
        "->",
        completion_strings[0].strip().split("\n")[0].strip(),
    )
    print(f"Spelling mean and std: {np.mean(rewards):.3f} +/- {np.std(rewards):.3f}")
    return rewards


assert reward_spelling(
    completions=[
        "H-E-L-L-O",
        "H-E-L-",
        "H-E-L-L-O!",
    ],
    word=[
        "hello",
        "hello",
        "hello",
    ],
) == [1, 3 / 9, 8 / 9]
# Out:
# =====
# Completion example first line: hello -> H-E-L-L-O
# Spelling mean and std: 0.741 +/- 0.292

# %%
# Student task: Create a reward of 1.0 for completions starting with a string
# formatted like X-Y-Z else return 0.0
# TODO: Replace sections marked with **********


def reward_response_in_form_of_letter_dash_letter(completions, word, **kwargs):
    """Reward function that gives a bonus for completions in the form of LETTER-DASH-LETTER."""
    pattern = re.compile(r"^([A-Z]-)+[A-Z]")  # Pattern for LETTER-DASH-LETTER

    words = [w for w in word]

    # Normalize the completions, taking the first line and removing extra whitespace
    completion_strings = [
        completion.split("\n")[0].strip() for completion in completions
    ]

    # Create a list of rewards corresponding to completions
    # Each completion that matches the pattern should receive 1.0,
    # else 0.0
    # rewards = [
    #     **********
    # ]

    # <<< START COMPLETION SECTION
    rewards = [
        1.0 if pattern.match(c) else 0.0 for w, c in zip(words, completion_strings)
    ]
    # >>> END COMPLETION SECTION

    print(
        f"Letter-dash-letter rewards mean and std: {np.mean(rewards):.3f} +/- {np.std(rewards):.3f}"
    )
    return rewards


assert reward_response_in_form_of_letter_dash_letter(
    completions=[
        "H-E-L-L-O",
        "hello",
        "Hi!",
    ],
    word=[
        "hello",
        "hello",
        "hello",
    ],
) == [1, 0, 0]
# Out:
# Letter-dash-letter rewards mean and std: 0.333 +/- 0.471

# %%
# Student task: Set the GRPOConfig and initialize the trainer
# See: https://huggingface.co/docs/trl/main/en/grpo_trainer
# TODO: Complete the sections with **********

from trl import GRPOConfig, GRPOTrainer

training_args = GRPOConfig(
    output_dir="data/spelling-grpo",
    max_completion_length=30,
    logging_steps=5,
    # learning_rate=**********,
    # num_train_epochs=**********,
    # per_device_train_batch_size=**********,
    # num_generations=**********,
    # lr_scheduler_type=**********,
    # beta=**********,
    learning_rate=5e-5,
    num_train_epochs=10,  # We'll train just for a few epochs
    per_device_train_batch_size=8,  # The batch size for training
    num_generations=4,  # Determines the number of completions to compute for each single prompt
    lr_scheduler_type="cosine",
    beta=0.0,
)
trainer = GRPOTrainer(
    model=model,
    # Add the parameter for the reward functions
    # **********
    reward_funcs=[
            reward_spelling,
            reward_response_in_form_of_letter_dash_letter,
        ],
    args=training_args,
    train_dataset=ds["train"],
)
trainer.train()
# Out:
#   0%|          | 0/280 [00:00<?, ?it/s]
# =====
# Completion example first line: mirth -> M-I-T-, W-R-I-D-O.
# Spelling mean and std: -0.109 +/- 0.405
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: mantle -> M-T-N-W-E.
# Spelling mean and std: -0.075 +/- 0.425
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: summit -> S-U-M-T-O.
# Spelling mean and std: -0.068 +/- 0.327
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: absolve -> A-B-E-R-S-F-I-U-V-E-R-S-S.
# Spelling mean and std: -0.034 +/- 0.327
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-Y.
# Spelling mean and std: 0.141 +/- 0.447
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# {'loss': -0.0, 'grad_norm': 0.2665660083293915, 'learning_rate': 4.996067037544542e-05, 'rewards/reward_spelling': -0.028951600193977356, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.9, 'reward': 0.8710484266281128, 'reward_std': 0.5695460379123688, 'completion_length': 30.0, 'kl': 0.4516123652458191, 'epoch': 0.18}
# =====
# Completion example first line: resolve -> E-R-S-Q-O-R-D.
# Spelling mean and std: 0.065 +/- 0.084
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: tavern -> T-A-A-A-N.
# Spelling mean and std: -0.017 +/- 0.270
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: brawn -> B-R-A-Y.
# Spelling mean and std: 0.167 +/- 0.299
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-A-P-I-B-L.
# Spelling mean and std: 0.069 +/- 0.199
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-A-M-I-N.
# Spelling mean and std: -0.151 +/- 0.548
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.19572104513645172, 'learning_rate': 4.984280524733107e-05, 'rewards/reward_spelling': 0.026366965472698213, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.0013669967651366, 'reward_std': 0.30157190561294556, 'completion_length': 30.0, 'kl': 0.36742904782295227, 'epoch': 0.36}
# =====
# Completion example first line: rust -> R-I-T-E-D.
# Spelling mean and std: 0.021 +/- 0.409
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-H-E-R.
# Spelling mean and std: -0.044 +/- 0.255
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: crisp -> C-R-I-S-P.
# Spelling mean and std: 0.347 +/- 0.326
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-R-E-L-O-M.
# Spelling mean and std: -0.060 +/- 0.444
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-E-S-A-T-R.
# Spelling mean and std: 0.063 +/- 0.301
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.23643805086612701, 'learning_rate': 4.96467754629559e-05, 'rewards/reward_spelling': 0.06537352055311203, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.0653735041618346, 'reward_std': 0.302959007024765, 'completion_length': 30.0, 'kl': 0.42253602147102354, 'epoch': 0.54}
# =====
# Completion example first line: glow -> G-L-O-W-I-N.
# Spelling mean and std: 0.000 +/- 0.353
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> W-O-R-D-I-N.
# Spelling mean and std: -0.173 +/- 0.438
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> VER-ge
# Spelling mean and std: -0.215 +/- 0.295
# Letter-dash-letter rewards mean and std: 0.625 +/- 0.484
# =====
# Completion example first line: mirage -> M-I-E-G-R-E.
# Spelling mean and std: -0.023 +/- 0.423
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: void -> V-O-N.
# Spelling mean and std: -0.012 +/- 0.207
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.34253740310668945, 'learning_rate': 4.937319780454559e-05, 'rewards/reward_spelling': -0.0844710849225521, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.9, 'reward': 0.8155289411544799, 'reward_std': 0.4320384204387665, 'completion_length': 30.0, 'kl': 0.39575731158256533, 'epoch': 0.71}
# =====
# Completion example first line: echo -> E-S-O-R.
# Spelling mean and std: 0.018 +/- 0.271
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: frescos -> F-S-R-E-C-O.
# Spelling mean and std: 0.077 +/- 0.200
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-O-R-A-N.
# Spelling mean and std: 0.282 +/- 0.143
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-S.
# Spelling mean and std: 0.309 +/- 0.255
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-R-R-I-N.
# Spelling mean and std: 0.216 +/- 0.251
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.3026571571826935, 'learning_rate': 4.9022933048627496e-05, 'rewards/reward_spelling': 0.18036686517298223, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.1553669095039367, 'reward_std': 0.23916010409593583, 'completion_length': 30.0, 'kl': 0.4575298190116882, 'epoch': 0.89}
# =====
# Completion example first line: cipher -> C-A-F-E-U-R-S.
# Spelling mean and std: 0.167 +/- 0.458
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-U-A-D.
# Spelling mean and std: 0.096 +/- 0.441
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: orchard -> O-R-D-E-H.
# Spelling mean and std: 0.000 +/- 0.077
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fusion -> F-U-R-T-I-A.
# Spelling mean and std: -0.045 +/- 0.208
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-S-P-E-R-I.
# Spelling mean and std: 0.397 +/- 0.297
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.1712874323129654, 'learning_rate': 4.8597083257709194e-05, 'rewards/reward_spelling': 0.12294650077819824, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.0979464888572692, 'reward_std': 0.31475342959165575, 'completion_length': 30.0, 'kl': 0.44403395652770994, 'epoch': 1.07}
# =====
# Completion example first line: sphinx -> S-P-H-K.
# Spelling mean and std: -0.068 +/- 0.231
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-E-R-L-O-U-N.
# Spelling mean and std: 0.163 +/- 0.160
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> g-R-N.
# Spelling mean and std: 0.088 +/- 0.239
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: brawn -> B-R-A-Y.
# Spelling mean and std: 0.425 +/- 0.253
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-A-P-I-C-I-O-R.
# Spelling mean and std: 0.138 +/- 0.192
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.18054956197738647, 'learning_rate': 4.8096988312782174e-05, 'rewards/reward_spelling': 0.14895993024110793, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.1239599347114564, 'reward_std': 0.25233012437820435, 'completion_length': 30.0, 'kl': 0.4203386068344116, 'epoch': 1.25}
# =====
# Completion example first line: ivory -> I-V-Y-O-O.
# Spelling mean and std: 0.400 +/- 0.357
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: velvet -> V-E-L-T-E-R.
# Spelling mean and std: 0.415 +/- 0.382
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-N-B-N-E.
# Spelling mean and std: -0.012 +/- 0.192
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: aperture -> A-R-P-E-R-T-O-N.
# Spelling mean and std: 0.301 +/- 0.341
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-T-E-R.
# Spelling mean and std: 0.188 +/- 0.329
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.1683979034423828, 'learning_rate': 4.752422169756048e-05, 'rewards/reward_spelling': 0.2585092715919018, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.95, 'reward': 1.2085092544555665, 'reward_std': 0.3952361762523651, 'completion_length': 30.0, 'kl': 0.44363426566123965, 'epoch': 1.43}
# =====
# Completion example first line: verge -> V-E-R-Y.
# Spelling mean and std: 0.024 +/- 0.354
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-S-R-E-C-O.
# Spelling mean and std: 0.279 +/- 0.133
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-Y-M.
# Spelling mean and std: 0.097 +/- 0.179
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-M-A-H.
# Spelling mean and std: -0.049 +/- 0.291
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: scarab -> S-C-A-R-E-B.
# Spelling mean and std: 0.234 +/- 0.273
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.1612975150346756, 'learning_rate': 4.6880585547718845e-05, 'rewards/reward_spelling': 0.11698857098817825, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.0919885873794555, 'reward_std': 0.252259624004364, 'completion_length': 30.0, 'kl': 0.406591409444809, 'epoch': 1.61}
# =====
# Completion example first line: void -> V-O-O.
# Spelling mean and std: 0.034 +/- 0.408
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-E-U-D-A-L.
# Spelling mean and std: 0.222 +/- 0.215
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: idea -> I-D-E-O.
# Spelling mean and std: 0.430 +/- 0.213
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: aisle -> A-I-S-E-L-U-H or a-I-S-E-L-U-H.
# Spelling mean and std: 0.093 +/- 0.713
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-R-I-M-P-O-W-I-D.
# Spelling mean and std: -0.048 +/- 0.101
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.2724091112613678, 'learning_rate': 4.6168104980707107e-05, 'rewards/reward_spelling': 0.14628705009818077, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.1212870478630066, 'reward_std': 0.39889998733997345, 'completion_length': 30.0, 'kl': 0.4486650824546814, 'epoch': 1.79}
# =====
# Completion example first line: radius -> R-E-S-E-N.
# Spelling mean and std: 0.036 +/- 0.277
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: eclipse -> E-E-C-L-O-S.
# Spelling mean and std: 0.029 +/- 0.180
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-A-Z-E.
# Spelling mean and std: 0.236 +/- 0.264
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-O-V-R-E.
# Spelling mean and std: -0.010 +/- 0.228
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-E-L-O-A.
# Spelling mean and std: -0.202 +/- 0.535
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# {'loss': 0.0, 'grad_norm': 0.25578898191452026, 'learning_rate': 4.538902172398151e-05, 'rewards/reward_spelling': 0.017857144027948378, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 0.9928571581840515, 'reward_std': 0.35027931034564974, 'completion_length': 30.0, 'kl': 0.4834087610244751, 'epoch': 1.96}
# =====
# Completion example first line: expose -> E-P-S-T.
# Spelling mean and std: 0.136 +/- 0.429
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-E-N-Y.
# Spelling mean and std: 0.080 +/- 0.191
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-E-A-N.
# Spelling mean and std: 0.201 +/- 0.345
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fusion -> F-V-I-S-T.
# Spelling mean and std: 0.167 +/- 0.253
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-A-P-Y-A-L.
# Spelling mean and std: 0.411 +/- 0.374
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.13316263258457184, 'learning_rate': 4.454578706170075e-05, 'rewards/reward_spelling': 0.1988472670316696, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.198847246170044, 'reward_std': 0.26366554796695707, 'completion_length': 30.0, 'kl': 0.3587067425251007, 'epoch': 2.14}
# =====
# Completion example first line: lantern -> L-A-N-N-T-I.
# Spelling mean and std: 0.308 +/- 0.243
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: wisp -> W-I-S-P-E-R-I-N-G.
# Spelling mean and std: -0.143 +/- 0.293
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-R-W-I.
# Spelling mean and std: -0.029 +/- 0.462
# Letter-dash-letter rewards mean and std: 0.750 +/- 0.433
# =====
# Completion example first line: knit -> W-I-M-I-T.
# Spelling mean and std: -0.221 +/- 0.356
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: plow -> P-L-O-R-O.
# Spelling mean and std: 0.104 +/- 0.201
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.2285313755273819, 'learning_rate': 4.364105412207914e-05, 'rewards/reward_spelling': 0.0037823334336280824, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.95, 'reward': 0.9537823319435119, 'reward_std': 0.31829528212547303, 'completion_length': 30.0, 'kl': 0.38335479497909547, 'epoch': 2.32}
# =====
# Completion example first line: gossipy -> W-O-R-D.
# Spelling mean and std: 0.213 +/- 0.349
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-N-T-E-L.
# Spelling mean and std: 0.166 +/- 0.276
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-O-S-R-A-T.
# Spelling mean and std: 0.112 +/- 0.210
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-O-S-C-I-V-E.
# Spelling mean and std: 0.316 +/- 0.180
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-R-I-M-P-O-C.
# Spelling mean and std: 0.173 +/- 0.148
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.3149508833885193, 'learning_rate': 4.267766952966369e-05, 'rewards/reward_spelling': 0.19610390514135362, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.1961039066314698, 'reward_std': 0.2013131707906723, 'completion_length': 30.0, 'kl': 0.43934338688850405, 'epoch': 2.5}
# =====
# Completion example first line: relish -> R-E-L-D-I-S-H.
# Spelling mean and std: 0.138 +/- 0.109
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-N-B-N-O-R.
# Spelling mean and std: 0.042 +/- 0.397
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-I-U-M-R-E.
# Spelling mean and std: -0.139 +/- 0.309
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: radius -> R-A-M-S.
# Spelling mean and std: 0.182 +/- 0.187
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-R-E-L-U-N-L-A-R-I-N-O.
# Spelling mean and std: 0.053 +/- 0.165
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.33410021662712097, 'learning_rate': 4.16586644488001e-05, 'rewards/reward_spelling': 0.05528915598988533, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.0552891612052917, 'reward_std': 0.232231268286705, 'completion_length': 30.0, 'kl': 0.40468867421150206, 'epoch': 2.68}
# =====
# Completion example first line: zealous -> Z-E-L-O-S.
# Spelling mean and std: 0.209 +/- 0.389
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-R-T-I.
# Spelling mean and std: 0.353 +/- 0.293
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-D-E-H.
# Spelling mean and std: -0.019 +/- 0.107
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E-I.
# Spelling mean and std: 0.395 +/- 0.335
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-O-T-I-N-S.
# Spelling mean and std: -0.061 +/- 0.332
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.23012614250183105, 'learning_rate': 4.058724504646834e-05, 'rewards/reward_spelling': 0.1753724157810211, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.1753724336624145, 'reward_std': 0.2882911294698715, 'completion_length': 30.0, 'kl': 0.38175212144851683, 'epoch': 2.86}
# =====
# Completion example first line: ivory -> I-V-H-O-Y-I-O.
# Spelling mean and std: 0.083 +/- 0.182
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirage -> M-I-A-R-E.
# Spelling mean and std: 0.302 +/- 0.298
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-H-O-R-D.
# Spelling mean and std: -0.141 +/- 0.327
# Letter-dash-letter rewards mean and std: 0.750 +/- 0.433
# =====
# Completion example first line: glow -> G-L-O-V-H.
# Spelling mean and std: 0.500 +/- 0.237
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: veto -> V-O-T-E.
# Spelling mean and std: 0.203 +/- 0.138
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.3176030218601227, 'learning_rate': 3.946678240449515e-05, 'rewards/reward_spelling': 0.1894577607512474, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.95, 'reward': 1.1394577622413635, 'reward_std': 0.2903339385986328, 'completion_length': 30.0, 'kl': 0.4441171109676361, 'epoch': 3.04}
# =====
# Completion example first line: mosaic -> M-A-S-I-C-T.
# Spelling mean and std: 0.211 +/- 0.330
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-E-L-T-O-V-E-R.
# Spelling mean and std: 0.302 +/- 0.377
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: glow -> G-L-O-W.
# Spelling mean and std: 0.101 +/- 0.481
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-R-B-E-U-V.
# Spelling mean and std: 0.183 +/- 0.231
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-C-H-D.
# Spelling mean and std: 0.196 +/- 0.178
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.15308645367622375, 'learning_rate': 3.830080191288342e-05, 'rewards/reward_spelling': 0.19852648079395294, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.1985264778137208, 'reward_std': 0.3016314595937729, 'completion_length': 30.0, 'kl': 0.48942441344261167, 'epoch': 3.21}
# =====
# Completion example first line: aisle -> A-I-S-L-E.
# Spelling mean and std: 0.437 +/- 0.209
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> ZE-u-l-e-al.
# Spelling mean and std: 0.060 +/- 0.496
# Letter-dash-letter rewards mean and std: 0.625 +/- 0.484
# =====
# Completion example first line: rust -> R-O-T-S.
# Spelling mean and std: 0.018 +/- 0.381
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-Y-I-N.
# Spelling mean and std: 0.282 +/- 0.185
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fusion -> F-U-S-I-A.
# Spelling mean and std: 0.193 +/- 0.179
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.2535727024078369, 'learning_rate': 3.7092972177631e-05, 'rewards/reward_spelling': 0.19800200313329697, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.925, 'reward': 1.1230019807815552, 'reward_std': 0.40378537476062776, 'completion_length': 30.0, 'kl': 0.3945481777191162, 'epoch': 3.39}
# =====
# Completion example first line: lunar -> L-U-R-A-Z.
# Spelling mean and std: 0.194 +/- 0.308
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: radius -> R-A-S-I-O.
# Spelling mean and std: 0.251 +/- 0.239
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: eclipse -> E-E-C-O-M-E.
# Spelling mean and std: 0.057 +/- 0.132
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-O-R-M-E.
# Spelling mean and std: -0.049 +/- 0.137
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-R-M-I.
# Spelling mean and std: 0.286 +/- 0.474
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.2250971645116806, 'learning_rate': 3.5847093477938956e-05, 'rewards/reward_spelling': 0.14790432304143905, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.147904348373413, 'reward_std': 0.26554564833641053, 'completion_length': 30.0, 'kl': 0.503569370508194, 'epoch': 3.57}
# =====
# Completion example first line: tavern -> T-A-A-N.
# Spelling mean and std: -0.034 +/- 0.157
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: wisp -> W-O-P-I-S-E.
# Spelling mean and std: -0.018 +/- 0.364
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.357 +/- 0.303
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-A-Z-E.
# Spelling mean and std: 0.190 +/- 0.366
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-R-E-L-U-N-L-O-R.
# Spelling mean and std: 0.245 +/- 0.186
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.3421766757965088, 'learning_rate': 3.456708580912725e-05, 'rewards/reward_spelling': 0.1478826753795147, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.1478826761245728, 'reward_std': 0.2587544798851013, 'completion_length': 30.0, 'kl': 0.41635475158691404, 'epoch': 3.75}
# =====
# Completion example first line: resolve -> R-E-S-I-S-P.
# Spelling mean and std: 0.220 +/- 0.187
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> N-I-K-T.
# Spelling mean and std: -0.081 +/- 0.485
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: echo -> E-A-C-H-R-O.
# Spelling mean and std: 0.084 +/- 0.477
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-U-M-T-I-N.
# Spelling mean and std: -0.017 +/- 0.358
# Letter-dash-letter rewards mean and std: 0.750 +/- 0.433
# =====
# Completion example first line: frescos -> F-S-S-C-O-S-I.
# Spelling mean and std: 0.087 +/- 0.130
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.19096671044826508, 'learning_rate': 3.3256976548879184e-05, 'rewards/reward_spelling': 0.058616386353969575, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.925, 'reward': 0.9836163759231568, 'reward_std': 0.38959736526012423, 'completion_length': 30.0, 'kl': 0.4535364925861359, 'epoch': 3.93}
# =====
# Completion example first line: aperture -> A-P-R-E-T-O-R.
# Spelling mean and std: 0.183 +/- 0.196
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: crisp -> C-I-R-S-P-E-R-I.
# Spelling mean and std: 0.444 +/- 0.471
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-O-S-H-O-P.
# Spelling mean and std: 0.192 +/- 0.218
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-L-O-V-E.
# Spelling mean and std: 0.186 +/- 0.238
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: idea -> I-D-E-R.
# Spelling mean and std: 0.250 +/- 0.362
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.18895351886749268, 'learning_rate': 3.1920887785621235e-05, 'rewards/reward_spelling': 0.25104507207870486, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.2260451078414918, 'reward_std': 0.3506768226623535, 'completion_length': 30.0, 'kl': 0.5415284156799316, 'epoch': 4.11}
# =====
# Completion example first line: relish -> R-E-L-I-S-S.
# Spelling mean and std: 0.352 +/- 0.344
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E
# Spelling mean and std: 0.371 +/- 0.458
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-R-S-U-S-E-C-O-S.
# Spelling mean and std: 0.266 +/- 0.234
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fusion -> F-U-S-E-R.
# Spelling mean and std: 0.191 +/- 0.353
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: velvet -> V-E-L-T-O.
# Spelling mean and std: 0.282 +/- 0.141
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.33107835054397583, 'learning_rate': 3.056302334890786e-05, 'rewards/reward_spelling': 0.29227995574474336, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.2672799587249757, 'reward_std': 0.3437923938035965, 'completion_length': 30.0, 'kl': 0.6595519781112671, 'epoch': 4.29}
# =====
# Completion example first line: glow -> G-O-L-W.
# Spelling mean and std: 0.250 +/- 0.390
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> W-H-I-S-I-N.
# Spelling mean and std: -0.272 +/- 0.314
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-T-E.
# Spelling mean and std: 0.333 +/- 0.266
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-A-M-I-N-T.
# Spelling mean and std: 0.170 +/- 0.171
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-R-B-I-Z.
# Spelling mean and std: 0.000 +/- 0.149
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.29907605051994324, 'learning_rate': 2.918765558261841e-05, 'rewards/reward_spelling': 0.09636198021471501, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.0963619709014893, 'reward_std': 0.25100515484809877, 'completion_length': 30.0, 'kl': 0.47143241167068484, 'epoch': 4.46}
# =====
# Completion example first line: banner -> B-N-A-N-B.
# Spelling mean and std: 0.057 +/- 0.186
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-R-U-M-P-H.
# Spelling mean and std: 0.145 +/- 0.223
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-C-R-B-A.
# Spelling mean and std: 0.494 +/- 0.251
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-D.
# Spelling mean and std: 0.109 +/- 0.229
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: tavern -> T-A-A-R-N.
# Spelling mean and std: 0.263 +/- 0.344
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.3277876079082489, 'learning_rate': 2.7799111902582696e-05, 'rewards/reward_spelling': 0.21350871697068213, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.2135087251663208, 'reward_std': 0.1982875496149063, 'completion_length': 29.975, 'kl': 0.43451990485191344, 'epoch': 4.64}
# =====
# Completion example first line: oath -> O-A-T-H.
# Spelling mean and std: 0.424 +/- 0.382
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sphinx -> S-Pox-N-I-S.
# Spelling mean and std: -0.039 +/- 0.330
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-O-T-I-N-G.
# Spelling mean and std: -0.446 +/- 0.275
# Letter-dash-letter rewards mean and std: 0.625 +/- 0.484
# =====
# Completion example first line: aperture -> A-R-P-E-R-T-U.
# Spelling mean and std: 0.062 +/- 0.155
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-A-N-Y.
# Spelling mean and std: 0.081 +/- 0.253
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.1649617701768875, 'learning_rate': 2.6401761180929797e-05, 'rewards/reward_spelling': 0.016398046910762788, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.925, 'reward': 0.9413980662822723, 'reward_std': 0.31629825234413145, 'completion_length': 30.0, 'kl': 0.4214414060115814, 'epoch': 4.82}
# =====
# Completion example first line: elude -> E-L-E-A-D.
# Spelling mean and std: 0.528 +/- 0.367
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-R-D-E.
# Spelling mean and std: -0.035 +/- 0.118
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: enchant -> C-N-H-E-T-E-N.
# Spelling mean and std: -0.029 +/- 0.317
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: radius -> R-I-G-S-T.
# Spelling mean and std: 0.085 +/- 0.256
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-R-C-H.
# Spelling mean and std: -0.143 +/- 0.143
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.3330637514591217, 'learning_rate': 2.5e-05, 'rewards/reward_spelling': 0.0811799332499504, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.056179928779602, 'reward_std': 0.22450603246688844, 'completion_length': 29.95, 'kl': 0.5480222225189209, 'epoch': 5.0}
# =====
# Completion example first line: grim -> G-R-R-M.
# Spelling mean and std: 0.320 +/- 0.266
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> - M-S-I-T-I-T-A.
# Spelling mean and std: -0.023 +/- 0.333
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: tavern -> T-A-A-N.
# Spelling mean and std: 0.116 +/- 0.192
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-R-E-U.
# Spelling mean and std: 0.104 +/- 0.450
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-Y-O-U-I-N.
# Spelling mean and std: 0.177 +/- 0.195
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.187811940908432, 'learning_rate': 2.3598238819070202e-05, 'rewards/reward_spelling': 0.13884449377655983, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.1138445138931274, 'reward_std': 0.3120502486824989, 'completion_length': 30.0, 'kl': 0.7275265872478485, 'epoch': 5.18}
# =====
# Completion example first line: mirth -> M-I-T-E-R.
# Spelling mean and std: 0.310 +/- 0.188
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> N-I-T-E-R.
# Spelling mean and std: -0.071 +/- 0.316
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-R-P-E-R-T-O.
# Spelling mean and std: 0.183 +/- 0.233
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-E-L-T.
# Spelling mean and std: -0.011 +/- 0.167
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E-S.
# Spelling mean and std: 0.440 +/- 0.297
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.27451133728027344, 'learning_rate': 2.2200888097417307e-05, 'rewards/reward_spelling': 0.16998613104224206, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.1699861288070679, 'reward_std': 0.22658895552158356, 'completion_length': 30.0, 'kl': 0.44321033358573914, 'epoch': 5.36}
# =====
# Completion example first line: elude -> E-L-E-U-A.
# Spelling mean and std: 0.241 +/- 0.224
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-E-R-U.
# Spelling mean and std: 0.090 +/- 0.129
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: crisp -> C-R-I-S-P.
# Spelling mean and std: 0.301 +/- 0.360
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-R-I-L-E.
# Spelling mean and std: 0.234 +/- 0.213
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-O-R-U-N.
# Spelling mean and std: 0.192 +/- 0.200
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.19064459204673767, 'learning_rate': 2.0812344417381595e-05, 'rewards/reward_spelling': 0.21142745912075042, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.2114274740219115, 'reward_std': 0.1993904799222946, 'completion_length': 30.0, 'kl': 0.3929060995578766, 'epoch': 5.54}
# =====
# Completion example first line: relish -> R-E-L-L-I-S.
# Spelling mean and std: 0.208 +/- 0.446
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-N-B-N-O.
# Spelling mean and std: 0.135 +/- 0.125
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-R-K-A-B.
# Spelling mean and std: 0.554 +/- 0.346
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-N-S.
# Spelling mean and std: 0.204 +/- 0.228
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-T-H.
# Spelling mean and std: 0.401 +/- 0.319
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.2995541989803314, 'learning_rate': 1.9436976651092144e-05, 'rewards/reward_spelling': 0.3002741813659668, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.3002742290496827, 'reward_std': 0.22633568346500396, 'completion_length': 30.0, 'kl': 0.49496362805366517, 'epoch': 5.71}
# =====
# Completion example first line: resolve -> R-I-S-S-E.
# Spelling mean and std: 0.015 +/- 0.178
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> W-H-I-T.
# Spelling mean and std: -0.026 +/- 0.163
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-U-P-A-T-E.
# Spelling mean and std: 0.008 +/- 0.201
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-E-D.
# Spelling mean and std: -0.048 +/- 0.108
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aisle -> A-I-S-L-E-S-I.
# Spelling mean and std: 0.498 +/- 0.347
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.27256426215171814, 'learning_rate': 1.8079112214378768e-05, 'rewards/reward_spelling': 0.08936341442167758, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.0893634557724, 'reward_std': 0.20406440049409866, 'completion_length': 29.875, 'kl': 0.46962110996246337, 'epoch': 5.89}
# =====
# Completion example first line: verge -> VER-ge.
# Spelling mean and std: 0.347 +/- 0.445
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: gaze -> G-A-E-N-E.
# Spelling mean and std: 0.232 +/- 0.226
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: expose -> E-S-P-O-R-D.
# Spelling mean and std: 0.205 +/- 0.276
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-H-O-R-P-I-Z-I.
# Spelling mean and std: 0.239 +/- 0.254
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-L-E-T-U-V-E-T.
# Spelling mean and std: 0.034 +/- 0.265
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.2746436893939972, 'learning_rate': 1.6743023451120832e-05, 'rewards/reward_spelling': 0.2114024981856346, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.1864025592803955, 'reward_std': 0.36698280572891234, 'completion_length': 30.0, 'kl': 0.7680674016475677, 'epoch': 6.07}
# =====
# Completion example first line: grim -> G-R-R-M.
# Spelling mean and std: 0.177 +/- 0.179
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-A-U-T-E.
# Spelling mean and std: -0.010 +/- 0.165
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-O-T-S.
# Spelling mean and std: 0.196 +/- 0.539
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-N-B-N-R.
# Spelling mean and std: 0.271 +/- 0.371
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-O-A-D.
# Spelling mean and std: 0.200 +/- 0.217
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.34155571460723877, 'learning_rate': 1.5432914190872757e-05, 'rewards/reward_spelling': 0.16693029552698135, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.1669303178787231, 'reward_std': 0.2381708174943924, 'completion_length': 30.0, 'kl': 0.9069816052913666, 'epoch': 6.25}
# =====
# Completion example first line: torrent -> T-R-U-A-C-I-N.
# Spelling mean and std: 0.183 +/- 0.512
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: mosaic -> M-A-S-S-I.
# Spelling mean and std: 0.166 +/- 0.206
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-R-U-M-P-H.
# Spelling mean and std: 0.150 +/- 0.255
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-T-E.
# Spelling mean and std: 0.050 +/- 0.226
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: expose -> E-X-P-S-T.
# Spelling mean and std: 0.057 +/- 0.204
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.3140585124492645, 'learning_rate': 1.4152906522061048e-05, 'rewards/reward_spelling': 0.1211094468832016, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.95, 'reward': 1.071109449863434, 'reward_std': 0.37810101807117463, 'completion_length': 30.0, 'kl': 0.6550769150257111, 'epoch': 6.43}
# =====
# Completion example first line: aperture -> A-P-R-E-T-A-R-O.
# Spelling mean and std: 0.181 +/- 0.155
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-R-B-U-V-E.
# Spelling mean and std: 0.026 +/- 0.187
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-A-D-I-R-O.
# Spelling mean and std: 0.365 +/- 0.422
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-N-P-T-E.
# Spelling mean and std: 0.244 +/- 0.143
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-S-I-V-E.
# Spelling mean and std: 0.371 +/- 0.157
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.2800683081150055, 'learning_rate': 1.2907027822369005e-05, 'rewards/reward_spelling': 0.2373720794916153, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.237372088432312, 'reward_std': 0.15959004759788514, 'completion_length': 30.0, 'kl': 0.41391823887825013, 'epoch': 6.61}
# =====
# Completion example first line: scarab -> S-A-C-R-A-B.
# Spelling mean and std: 0.151 +/- 0.285
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-L-O-V-E.
# Spelling mean and std: 0.243 +/- 0.261
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-E-N-A-W.
# Spelling mean and std: 0.292 +/- 0.146
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-U-B-E.
# Spelling mean and std: 0.196 +/- 0.224
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-S-E-T-I-N-S-O.
# Spelling mean and std: 0.163 +/- 0.192
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.2939591407775879, 'learning_rate': 1.1699198087116589e-05, 'rewards/reward_spelling': 0.2088855594396591, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.2088855743408202, 'reward_std': 0.23998059034347535, 'completion_length': 30.0, 'kl': 0.40519259572029115, 'epoch': 6.79}
# =====
# Completion example first line: idea -> I-D-O-R-A.
# Spelling mean and std: 0.304 +/- 0.338
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> N-I-K-T.
# Spelling mean and std: -0.288 +/- 0.464
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: maze -> M-E-A-S-U-R-I-S.
# Spelling mean and std: 0.071 +/- 0.536
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> V-U-R-E-G.
# Spelling mean and std: 0.249 +/- 0.162
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sphinx -> S-P-H-I-N-K.
# Spelling mean and std: 0.532 +/- 0.118
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.23549582064151764, 'learning_rate': 1.0533217595504858e-05, 'rewards/reward_spelling': 0.17359696626663207, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.1485969781875611, 'reward_std': 0.3144304841756821, 'completion_length': 30.0, 'kl': 0.4578529894351959, 'epoch': 6.96}
# =====
# Completion example first line: veto -> V-O-T-E-O.
# Spelling mean and std: 0.357 +/- 0.237
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-O-T.
# Spelling mean and std: 0.030 +/- 0.270
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-O-R-A-T.
# Spelling mean and std: -0.002 +/- 0.273
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: ember -> E-M-U-R-I-E.
# Spelling mean and std: 0.138 +/- 0.086
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-A-M-E-L.
# Spelling mean and std: -0.286 +/- 0.326
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.2394075095653534, 'learning_rate': 9.412754953531663e-06, 'rewards/reward_spelling': 0.047335998713970186, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.022335982322693, 'reward_std': 0.2580363914370537, 'completion_length': 30.0, 'kl': 0.43477404713630674, 'epoch': 7.14}
# =====
# Completion example first line: cipher -> C-F-E-M-I-A.
# Spelling mean and std: -0.050 +/- 0.086
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> VER-e-ge
# Spelling mean and std: -0.043 +/- 0.312
# Letter-dash-letter rewards mean and std: 0.750 +/- 0.433
# =====
# Completion example first line: brawn -> B-R-A-N-Y.
# Spelling mean and std: 0.254 +/- 0.258
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-Y-O-R-Y.
# Spelling mean and std: 0.431 +/- 0.410
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: grim -> G-R-I-N-K.
# Spelling mean and std: 0.227 +/- 0.125
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.357699990272522, 'learning_rate': 8.341335551199902e-06, 'rewards/reward_spelling': 0.16390831246972085, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.925, 'reward': 1.088908314704895, 'reward_std': 0.3063799262046814, 'completion_length': 29.75, 'kl': 0.4339371144771576, 'epoch': 7.32}
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.422 +/- 0.404
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lantern -> L-A-N-T-I-N.
# Spelling mean and std: 0.309 +/- 0.197
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lunar -> L-U-R-R-Y.
# Spelling mean and std: 0.215 +/- 0.318
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-R-U-E.
# Spelling mean and std: 0.033 +/- 0.302
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: onset -> O-W-N-S-T.
# Spelling mean and std: 0.375 +/- 0.355
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# {'loss': -0.0, 'grad_norm': 0.2969168424606323, 'learning_rate': 7.3223304703363135e-06, 'rewards/reward_spelling': 0.27082640379667283, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.95, 'reward': 1.2208263993263244, 'reward_std': 0.39493856728076937, 'completion_length': 30.0, 'kl': 0.4564863383769989, 'epoch': 7.5}
# =====
# Completion example first line: scarab -> S-A-C-R-B-E.
# Spelling mean and std: 0.227 +/- 0.187
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-T-R-N.
# Spelling mean and std: 0.148 +/- 0.308
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-S-H.
# Spelling mean and std: 0.419 +/- 0.300
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-L-O.
# Spelling mean and std: 0.266 +/- 0.235
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-Z-E-R.
# Spelling mean and std: 0.304 +/- 0.290
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.21854162216186523, 'learning_rate': 6.358945877920861e-06, 'rewards/reward_spelling': 0.27259130477905275, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.2725913286209107, 'reward_std': 0.23813416361808776, 'completion_length': 30.0, 'kl': 0.4167784035205841, 'epoch': 7.68}
# =====
# Completion example first line: triumph -> T-R-I-M-P-H.
# Spelling mean and std: 0.205 +/- 0.096
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-R-I-L-E.
# Spelling mean and std: 0.307 +/- 0.143
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-S-R-O-C-I-S-S.
# Spelling mean and std: 0.327 +/- 0.242
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-U-P-I-K-A.
# Spelling mean and std: 0.040 +/- 0.179
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: plow -> P-L-O-W.
# Spelling mean and std: 0.401 +/- 0.319
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.33026841282844543, 'learning_rate': 5.454212938299258e-06, 'rewards/reward_spelling': 0.255844160169363, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.2558441877365112, 'reward_std': 0.15927731543779372, 'completion_length': 30.0, 'kl': 0.5355180978775025, 'epoch': 7.86}
# =====
# Completion example first line: wisp -> W-E-P-I-S.
# Spelling mean and std: 0.089 +/- 0.500
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-R-P-E-R-T-O.
# Spelling mean and std: 0.025 +/- 0.183
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> W-H-C-I-S-H.
# Spelling mean and std: 0.250 +/- 0.292
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-R-E-L-K-E-N-O.
# Spelling mean and std: 0.365 +/- 0.100
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-A-P-I-B-R.
# Spelling mean and std: 0.298 +/- 0.251
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.25470611453056335, 'learning_rate': 4.610978276018496e-06, 'rewards/reward_spelling': 0.2054578810930252, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.205457878112793, 'reward_std': 0.2594297394156456, 'completion_length': 30.0, 'kl': 0.46424260139465334, 'epoch': 8.04}
# =====
# Completion example first line: void -> V-O-F-A.
# Spelling mean and std: 0.433 +/- 0.333
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-R-I-U-M-P-H.
# Spelling mean and std: 0.317 +/- 0.259
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-U-M-T-E-R.
# Spelling mean and std: 0.227 +/- 0.315
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: eclipse -> e-s-c-l-u-p.
# Spelling mean and std: 0.069 +/- 0.283
# Letter-dash-letter rewards mean and std: 0.750 +/- 0.433
# =====
# Completion example first line: veto -> V-E-T-O.
# Spelling mean and std: 0.172 +/- 0.285
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.18506743013858795, 'learning_rate': 3.831895019292897e-06, 'rewards/reward_spelling': 0.24357587844133377, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.95, 'reward': 1.1935758709907531, 'reward_std': 0.3196569889783859, 'completion_length': 30.0, 'kl': 0.4719970941543579, 'epoch': 8.21}
# =====
# Completion example first line: enchant -> E-N-C-A-T-O.
# Spelling mean and std: 0.201 +/- 0.343
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-C-R-E-B.
# Spelling mean and std: 0.315 +/- 0.391
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirage -> M-I-F-E-R.
# Spelling mean and std: 0.184 +/- 0.147
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-O-S-K-O-P.
# Spelling mean and std: 0.337 +/- 0.191
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-n-ss.
# Spelling mean and std: -0.115 +/- 0.320
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# {'loss': 0.0, 'grad_norm': 0.2802113890647888, 'learning_rate': 3.119414452281158e-06, 'rewards/reward_spelling': 0.18410201519727706, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.1591020107269288, 'reward_std': 0.32975104749202727, 'completion_length': 30.0, 'kl': 0.4593376278877258, 'epoch': 8.39}
# =====
# Completion example first line: aperture -> A-R-P-E-R-O.
# Spelling mean and std: 0.210 +/- 0.354
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-S-E.
# Spelling mean and std: 0.346 +/- 0.273
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-S-L-E-D.
# Spelling mean and std: 0.270 +/- 0.234
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-ER.
# Spelling mean and std: 0.197 +/- 0.247
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-N-B-N-R-A.
# Spelling mean and std: 0.091 +/- 0.182
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.3046656548976898, 'learning_rate': 2.475778302439524e-06, 'rewards/reward_spelling': 0.2227711260318756, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.2227711439132691, 'reward_std': 0.2383064806461334, 'completion_length': 30.0, 'kl': 0.6856464922428132, 'epoch': 8.57}
# =====
# Completion example first line: knit -> N-I-T-I.
# Spelling mean and std: 0.052 +/- 0.286
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-E-M-E-A-I-R.
# Spelling mean and std: 0.172 +/- 0.288
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> W-O-R-C-H.
# Spelling mean and std: 0.089 +/- 0.197
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-I-S-S-E.
# Spelling mean and std: 0.355 +/- 0.136
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-C-O-R-H.
# Spelling mean and std: 0.141 +/- 0.242
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.14653554558753967, 'learning_rate': 1.9030116872178316e-06, 'rewards/reward_spelling': 0.16174381598830223, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.1617438316345214, 'reward_std': 0.1873305320739746, 'completion_length': 30.0, 'kl': 0.4415843546390533, 'epoch': 8.75}
# =====
# Completion example first line: crisp -> C-R-I-S-P.
# Spelling mean and std: 0.276 +/- 0.531
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: orchard -> O-R-C-H-E-D.
# Spelling mean and std: 0.376 +/- 0.413
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-Y-N.
# Spelling mean and std: 0.155 +/- 0.266
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-N-T-E-R.
# Spelling mean and std: 0.313 +/- 0.162
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-O-T.
# Spelling mean and std: 0.080 +/- 0.208
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.23227442800998688, 'learning_rate': 1.4029167422908107e-06, 'rewards/reward_spelling': 0.240023872256279, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.2150238513946534, 'reward_std': 0.2843771740794182, 'completion_length': 30.0, 'kl': 0.3977970123291016, 'epoch': 8.93}
# =====
# Completion example first line: mosaic -> M-A-S-T-I-Q.
# Spelling mean and std: 0.102 +/- 0.200
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: oath -> O-A-T-I-O.
# Spelling mean and std: 0.429 +/- 0.474
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: cipher -> C-A-F-I-N-S.
# Spelling mean and std: 0.181 +/- 0.212
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-A-P-E-R.
# Spelling mean and std: 0.154 +/- 0.224
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lantern -> L-A-N-T-I-N-E.
# Spelling mean and std: 0.433 +/- 0.066
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': -0.0, 'grad_norm': 0.22673456370830536, 'learning_rate': 9.770669513725128e-07, 'rewards/reward_spelling': 0.25958763957023623, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.975, 'reward': 1.2345876455307008, 'reward_std': 0.2694095879793167, 'completion_length': 30.0, 'kl': 0.4393730521202087, 'epoch': 9.11}
# =====
# Completion example first line: veto -> V-O-T-E-U.
# Spelling mean and std: 0.373 +/- 0.256
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-C-H-R.
# Spelling mean and std: 0.050 +/- 0.337
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-U-M-T-I-Z.
# Spelling mean and std: 0.144 +/- 0.260
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-A-L-I-C-H.
# Spelling mean and std: -0.037 +/- 0.162
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-N-T-E-L.
# Spelling mean and std: 0.250 +/- 0.217
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.2081555277109146, 'learning_rate': 6.268021954544096e-07, 'rewards/reward_spelling': 0.15611888393759726, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.156118893623352, 'reward_std': 0.24752597510814667, 'completion_length': 29.775, 'kl': 0.42576542496681213, 'epoch': 9.29}
# =====
# Completion example first line: zealous -> Z-E-O-L-I-O-S.
# Spelling mean and std: 0.244 +/- 0.293
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-E-A-L.
# Spelling mean and std: 0.282 +/- 0.141
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-O-T-E-R.
# Spelling mean and std: 0.370 +/- 0.240
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: plow -> P-O-W-E.
# Spelling mean and std: 0.294 +/- 0.345
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-T-E-S-I-A.
# Spelling mean and std: -0.044 +/- 0.228
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.20321305096149445, 'learning_rate': 3.5322453704410286e-07, 'rewards/reward_spelling': 0.22911477386951445, 'rewards/reward_response_in_form_of_letter_dash_letter': 1.0, 'reward': 1.2291147589683533, 'reward_std': 0.2349753737449646, 'completion_length': 30.0, 'kl': 0.5622704029083252, 'epoch': 9.46}
# =====
# Completion example first line: torrent -> T-O-R-A-N.
# Spelling mean and std: -0.266 +/- 0.397
# Letter-dash-letter rewards mean and std: 0.625 +/- 0.484
# =====
# Completion example first line: ivory -> I-V-O-Y-I-O.
# Spelling mean and std: 0.542 +/- 0.366
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-A-P-I-C-E.
# Spelling mean and std: 0.086 +/- 0.173
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-A-D-O.
# Spelling mean and std: -0.048 +/- 0.115
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-E-U-R-V-E.
# Spelling mean and std: 0.293 +/- 0.527
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# {'loss': 0.0, 'grad_norm': 0.3721785843372345, 'learning_rate': 1.571947526689349e-07, 'rewards/reward_spelling': 0.12108059227466583, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.9, 'reward': 1.021080619096756, 'reward_std': 0.3407892256975174, 'completion_length': 30.0, 'kl': 0.4129189610481262, 'epoch': 9.64}
# =====
# Completion example first line: mosaic -> M-A-S-I-C-T.
# Spelling mean and std: 0.281 +/- 0.196
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-D-E-S.
# Spelling mean and std: 0.088 +/- 0.183
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.536 +/- 0.333
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-A-I-S-E.
# Spelling mean and std: -0.041 +/- 0.385
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: mirth -> M-I-T-E.
# Spelling mean and std: -0.019 +/- 0.396
# Letter-dash-letter rewards mean and std: 0.750 +/- 0.433
# {'loss': 0.0, 'grad_norm': 0.4396917223930359, 'learning_rate': 3.9329624554584884e-08, 'rewards/reward_spelling': 0.16920579224824905, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.925, 'reward': 1.0942058563232422, 'reward_std': 0.3649730205535889, 'completion_length': 30.0, 'kl': 0.504511296749115, 'epoch': 9.82}
# =====
# Completion example first line: sphinx -> S-P-H-Y-K-E-N.
# Spelling mean and std: 0.557 +/- 0.269
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-O-T-E-R.
# Spelling mean and std: 0.081 +/- 0.181
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-S-E-I-N.
# Spelling mean and std: 0.200 +/- 0.472
# Letter-dash-letter rewards mean and std: 0.750 +/- 0.433
# =====
# Completion example first line: void -> V-O-T.
# Spelling mean and std: 0.266 +/- 0.375
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirage -> M-I-A-E-R.
# Spelling mean and std: 0.295 +/- 0.207
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# {'loss': 0.0, 'grad_norm': 0.405061274766922, 'learning_rate': 0.0, 'rewards/reward_spelling': 0.2800893634557724, 'rewards/reward_response_in_form_of_letter_dash_letter': 0.95, 'reward': 1.2300893545150757, 'reward_std': 0.33926752805709837, 'completion_length': 30.0, 'kl': 0.4368647038936615, 'epoch': 10.0}
# {'train_runtime': 298.3781, 'train_samples_per_second': 1.843, 'train_steps_per_second': 0.938, 'train_loss': 3.308190831116268e-08, 'epoch': 10.0}
# TrainOutput(global_step=280, training_loss=3.308190831116268e-08, metrics={'train_runtime': 298.3781, 'train_samples_per_second': 1.843, 'train_steps_per_second': 0.938, 'total_flos': 0.0, 'train_loss': 3.308190831116268e-08})

# %% [markdown]
# Now we define the `SFTTrainer` and run the fine-tuning process.

# %% [markdown]
# ## Step 5. Evaluate the fine-tuned model

# %%
# Evaluate the fine-tuned model on the same training examples
# No changes needed in this cell

proportion_correct = 0.0

for example in ds["train"].select(range(20)):
    prompt = example["prompt"]
    completion = example["completion"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=completion,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/20.0 words correct")
# Out:
# Proposed: T-R-I-M-P-O-V-I-Z. | Actual: T-R-I-U-M-P-H. | Matches: ❌
# Proposed: S-A-P-I-C-R-O. | Actual: S-A-P-P-H-I-R-E. | Matches: ❌
# Proposed: E-S-P-O-R-D. | Actual: E-X-P-O-S-E. | Matches: ❌
# Proposed: F-S-R-E-C-O-S. | Actual: F-R-E-S-C-O-S. | Matches: ❌
# Proposed: W-I-P-S-E. | Actual: W-I-S-P. | Matches: ❌
# Proposed: M-I-A-R-E. | Actual: M-I-R-A-G-E. | Matches: ❌
# Proposed: I-V-O-Y-I. | Actual: I-V-O-R-Y. | Matches: ❌
# Proposed: O-N-S-T-E-R. | Actual: O-N-S-E-T. | Matches: ❌
# Proposed: E-L-E-A-D. | Actual: E-L-U-D-E. | Matches: ❌
# Proposed: S-P-H-I-N-E. | Actual: S-P-H-I-N-X. | Matches: ❌
# Proposed: B-R-A-N-Y. | Actual: B-R-A-W-N. | Matches: ❌
# Proposed: G-O-S-H-O-P. | Actual: G-O-S-S-I-P-Y. | Matches: ❌
# Proposed: E-N-C-H-A-N. | Actual: E-N-C-H-A-N-T. | Matches: ❌
# Proposed: T-A-A-N. | Actual: T-A-V-E-R-N. | Matches: ❌
# Proposed: W-H-I-S-T. | Actual: W-H-I-S-T-L-E. | Matches: ❌
# Proposed: C-U-P-A-T-I-N. | Actual: C-A-P-T-U-R-E. | Matches: ❌
# Proposed: E-C-O-R-E. | Actual: E-C-H-O. | Matches: ❌
# Proposed: M-I-T-E-R. | Actual: M-I-R-T-H. | Matches: ❌
# Proposed: C-R-I-S-P. | Actual: C-R-I-S-P. | Matches: ✅
# Proposed: Z-E-A-L-O-V-E. | Actual: Z-E-A-L-O-U-S. | Matches: ❌
# 10.966666666666667/20.0 words correct

# %% [markdown]
# The model now performs better on the training data it has seen. But has it generalized? Let's check its performance on the unseen test set.

# %%
# Evaluate the fine-tuned model on the unseen test set
# No changes needed in this cell

proportion_correct = 0.0
num_examples = len(ds["test"])

for example in ds["test"]:
    prompt = example["prompt"]
    completion = example["completion"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=completion,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/{num_examples}.0 words correct")
# Out:
# Proposed: W-R-Y-I-L-Y. | Actual: W-R-Y-L-Y. | Matches: ❌
# Proposed: G-L-I-N-E. | Actual: G-L-I-S-T-E-N. | Matches: ❌
# Proposed: C-A-S-Q-E-R. | Actual: Q-U-E-S-T. | Matches: ❌
# Proposed: C-E-R-E-B-E. | Actual: C-R-A-V-E. | Matches: ❌
# Proposed: L-U-S-I-O. | Actual: L-U-S-H. | Matches: ❌
# Proposed: F-A-L-I-T. | Actual: F-A-B-L-E. | Matches: ❌
# Proposed: K-N-A-R-K. | Actual: K-N-A-C-K. | Matches: ❌
# 2.975/7.0 words correct

# %% [markdown]
# It looks like it has improved! Perhaps with a larger dataset and more training, it could get even better.

# %% [markdown]
# ## Congratulations for completing the exercise! 🎉
#
# ✅ You did it! You successfully fine-tuned a small language model using PEFT with LoRA to teach it a new skill: spelling! You saw how the base model failed completely at the task, and with a very small amount of data and a short training run, the model started to learn how to spell.

# %% [markdown]
# <br /><br /><br /><br /><br /><br /><br /><br /><br />
